# %%
# !git clone https://github.com/hanxiaoya/LLM.git

# %%
# !pip install -r LLM/langchain-ChatGLM/requirements.txt

# %%
# !git lfs install

# %%
pwd

# %%
# %cd LLM/langchain-ChatGLM/

# %%
pwd

# %%
# 下载 LLM 模型
# !git clone https://huggingface.co/THUDM/chatglm2-6b-int4 $PWD/chatglm2-6b-int4

# %%
# 下载 Embedding 模型
# !git clone https://huggingface.co/GanymedeNil/text2vec-large-chinese $PWD/text2vec

# %%
# !python webui.py

# %%
# !python cli_demo.py
